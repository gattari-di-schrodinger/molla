# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sp
import numpy as np

# %%
m=pd.read_csv('masse_cumulative.csv')
T=pd.read_csv('periodi.csv')
x=pd.read_csv('elongazione.csv')

# %% [markdown]
# T^2 vs m

# %%
T_m=T.mean()/5
T_s=T.std()/(5*np.sqrt(5))
m_m=m.mean()
m_s=m.std()
x_m=x.mean()
x_s=x.std()

# %%
T_qm=pow(T_m,2)
T_qs=2*T_m*T_s

# %%
plt.errorbar(m_m,T_qm,T_qs,color='black',uplims=True, lolims=True)
x=np.linspace(0,1)
y=0.6954940466383607*x+0.00022712619030662573
plt.plot(x,y)
plt.xlabel('massa in kg')
plt.ylabel('periodo^2 in s^2')
# Out:
# Text(0, 0.5, 'periodo^2 in s^2')

# %%
plt.plot(m,pow(T/5,2),'.',color='black')
plt.xlabel('massa in kg')
plt.ylabel('periodo^2 in s^2')
# Out:
# Text(0, 0.5, 'periodo^2 in s^2')

# %%
plt.errorbar(m_m,x_m,x_s,color='black',uplims=True, lolims=True)
plt.ylabel('spostamento in m')
plt.xlabel('massa in kg')
# Out:
# Text(0.5, 0, 'massa in kg')

# %%
plt.plot(m,x,'.',color='black')
plt.ylabel('spostamento in m')
plt.xlabel('massa in kg')
# Out:
# Text(0.5, 0, 'massa in kg')

# %%
plt.errorbar(T_qm,x_m,T_qs,x_s,color='black',uplims=True, lolims=True,xuplims=True, xlolims=True)
plt.xlabel('spostamento in m')
plt.ylabel('periodo^2 in s^2')
# Out:
# Text(0, 0.5, 'periodo^2 in s^2')

# %%
plt.plot(x,pow(T,2),'.',color='black')
plt.xlabel('spostamento in m')
plt.ylabel('periodo^2 in s^2')
# Out:
# Text(0, 0.5, 'periodo^2 in s^2')

# %% [markdown]
# retta approssimante

# %%
m_m=np.array(m_m)
T_qm=np.array(T_qm)

# %%
T_qm_=T_qm[2:]
m_m_=m_m[2:]

# %%
Tm=T_qm_.mean()
mm=m_m_.mean()

# %%
m_m_p=m_m_-mm
T_qm_p=T_qm_-Tm

# %%
S=np.dot(m_m_p,T_qm_p)
S_d=np.dot(m_m_p,m_m_p)
b=S/S_d
print(b)
# Out:
# 0.6954940466383607

# %%
c=Tm-mm*b
print(c)
# Out:
# 0.00022712619030662573
