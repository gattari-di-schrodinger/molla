# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sp
import numpy as np

# %%
m=pd.read_csv('masse_cumulative.csv')
T=pd.read_csv('periodi.csv')
x=pd.read_csv('elongazione.csv')

# %% [markdown]
# T^2 vs m

# %%
T_m=T.mean()/10
T_s=T.std()/10
m_m=m.mean()
m_s=m.std()
x_m=x.mean()
x_s=x.std()

# %%
T_qm=pow(T_m,2)
T_qs=2*T_m*T_s

# %%
plt.errorbar(m_m,T_qm,T_qs,color='black',uplims=True, lolims=True)
plt.xlabel('massa in kg')
plt.ylabel('periodo^2 in s^2')
# Out:
# Text(0, 0.5, 'periodo^2 in s^2')

# %%
plt.plot(m,pow(T/10,2),'.',color='black')
plt.xlabel('massa in kg')
plt.ylabel('periodo^2 in s^2')
# Out:
# Text(0, 0.5, 'periodo^2 in s^2')

# %%
plt.errorbar(m_m,x_m,x_s,color='black',uplims=True, lolims=True)
plt.ylabel('spostamento in m')
plt.xlabel('massa in kg')
# Out:
# Text(0.5, 0, 'massa in kg')

# %%
plt.plot(m,x,'.',color='black')
plt.ylabel('spostamento in m')
plt.xlabel('massa in kg')
# Out:
# Text(0.5, 0, 'massa in kg')

# %%
plt.errorbar(T_qm,x_m,T_qs,x_s,color='black',uplims=True, lolims=True,xuplims=upperlimits, xlolims=lowerlimits,)
plt.xlabel('spostamento in m')
plt.ylabel('periodo^2 in s^2')
# Out:
# Text(0, 0.5, 'periodo^2 in s^2')

# %%
plt.plot(x,pow(T,2),'.',color='black')
# Out:
# [<matplotlib.lines.Line2D at 0x7ff8e5f6f2d0>,
#  <matplotlib.lines.Line2D at 0x7ff8e5ec0190>,
#  <matplotlib.lines.Line2D at 0x7ff8e5ec0350>,
#  <matplotlib.lines.Line2D at 0x7ff8e5ec0510>,
#  <matplotlib.lines.Line2D at 0x7ff8e5ec06d0>,
#  <matplotlib.lines.Line2D at 0x7ff8e5ec0650>,
#  <matplotlib.lines.Line2D at 0x7ff8e5ec0a90>,
#  <matplotlib.lines.Line2D at 0x7ff8e5ec0c50>,
#  <matplotlib.lines.Line2D at 0x7ff8e5ec0e10>,
#  <matplotlib.lines.Line2D at 0x7ff8e5ec0890>]
